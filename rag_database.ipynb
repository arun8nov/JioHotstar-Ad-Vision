# %%
from dotenv import load_dotenv
load_dotenv()
import os

# Load environment variables from .env file
user = os.getenv("db_user")
password = os.getenv("db_password")
host = os.getenv("db_host")
port = os.getenv("db_port")
database = os.getenv("db_name")

# %%
from langchain_community.utilities import SQLDatabase
from langchain_community.llms import Ollama
from langchain_community.agent_toolkits.sql.base import create_sql_agent

db = SQLDatabase.from_uri(
    f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")   # Database Configuration

llm = Ollama(model = 'llama3.2:1b') # Local LLM Configuration

# Create the SQL Agent Executor
agent_executor = create_sql_agent(
    llm=llm,
    db=db,
    agent_type="openai-tools",
    verbose=True
)

# Ask questions in natural language!
answer = agent_executor.run("Show all tables in the database")
print(answer)
# Out:
# > Entering new SQL Agent Executor chain...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 19
#      11 agent_executor = create_sql_agent(
#      12     llm=llm,
#      13     db=db,
#      14     agent_type="openai-tools",
#      15     verbose=True
#      16 )
#      18 # Ask questions in natural language!
# ---> 19 answer = agent_executor.run("Show all tables in the database")
#      20 print(answer)
#
# File d:\GIT\JioHotstar-Ad-Vision\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:188, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     186     warned = True
#     187     emit_warning()
# --> 188 return wrapped(*args, **kwargs)
#
# File d:\GIT\JioHotstar-Ad-Vision\.venv\Lib\site-packages\langchain_classic\chains\base.py:632, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
# ...

# %%
import google.generativeai as genai
genai.configure(api_key=os.getenv("GOOGLE_GENAI_API_KEY"))
